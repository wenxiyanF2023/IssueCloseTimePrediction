# %%
import requests
from urllib.parse import urlparse, parse_qs
import dotenv
import os

dotenv.load_dotenv()
token = os.getenv('GITHUB_TOKEN')

def fetch_all_issues(repo, token):
    url = f'https://api.github.com/repos/{repo}/issues'
    
    headers = {
        'Authorization': f'token {token}',
        'Accept': 'application/vnd.github.v3+json',
    }
    
    params = {
        'state': 'closed', 
        'per_page': 100,
        'page': 1, 
    }
    
    all_issues = []
    page_number = 1

    while True:
        print(f'Fetching page number: {page_number}')
        response = requests.get(url, headers=headers, params=params)
        issues = response.json()
        
        if not issues:
            break
            
        for issue in issues:
            all_issues.append({
                'title': issue['title'],
                'body': issue.get('body', ''),
                'created_at': issue['created_at'],
                'closed_at': issue.get('closed_at'),
                'is_pull_request': 'pull_request' in issue,
                'author_association': issue['author_association'],
            })
        
        if 'next' in response.links:
            next_url = response.links['next']['url']
            parsed_url = urlparse(next_url)
            next_page_number = parse_qs(parsed_url.query)['page'][0]
            params['page'] = int(next_page_number)
            page_number = params['page']
        else:
            break
    
    return all_issues

repo = 'facebook/react'
issues = fetch_all_issues(repo, token)
print(f'Total issues fetched: {len(issues)}')
# Out:
# Fetching page number: 1
# Fetching page number: 2
# Fetching page number: 3
# Fetching page number: 4
# Fetching page number: 5
# Fetching page number: 6
# Fetching page number: 7
# Fetching page number: 8
# Fetching page number: 9
# Fetching page number: 10
# Fetching page number: 11
# Fetching page number: 12
# Fetching page number: 13
# Fetching page number: 14
# Fetching page number: 15
# Fetching page number: 16
# Fetching page number: 17
# Fetching page number: 18
# Fetching page number: 19
# Fetching page number: 20
# Fetching page number: 21
# Fetching page number: 22
# Fetching page number: 23
# Fetching page number: 24
# Fetching page number: 25
# Fetching page number: 26
# Fetching page number: 27
# Fetching page number: 28
# Fetching page number: 29
# Fetching page number: 30
# Fetching page number: 31
# Fetching page number: 32
# Fetching page number: 33
# Fetching page number: 34
# Fetching page number: 35
# Fetching page number: 36
# Fetching page number: 37
# Fetching page number: 38
# Fetching page number: 39
# Fetching page number: 40
# Fetching page number: 41
# Fetching page number: 42
# Fetching page number: 43
# Fetching page number: 44
# Fetching page number: 45
# Fetching page number: 46
# Fetching page number: 47
# Fetching page number: 48
# Fetching page number: 49
# Fetching page number: 50
# Fetching page number: 51
# Fetching page number: 52
# Fetching page number: 53
# Fetching page number: 54
# Fetching page number: 55
# Fetching page number: 56
# Fetching page number: 57
# Fetching page number: 58
# Fetching page number: 59
# Fetching page number: 60
# Fetching page number: 61
# Fetching page number: 62
# Fetching page number: 63
# Fetching page number: 64
# Fetching page number: 65
# Fetching page number: 66
# Fetching page number: 67
# Fetching page number: 68
# Fetching page number: 69
# Fetching page number: 70
# Fetching page number: 71
# Fetching page number: 72
# Fetching page number: 73
# Fetching page number: 74
# Fetching page number: 75
# Fetching page number: 76
# Fetching page number: 77
# Fetching page number: 78
# Fetching page number: 79
# Fetching page number: 80
# Fetching page number: 81
# Fetching page number: 82
# Fetching page number: 83
# Fetching page number: 84
# Fetching page number: 85
# Fetching page number: 86
# Fetching page number: 87
# Fetching page number: 88
# Fetching page number: 89
# Fetching page number: 90
# Fetching page number: 91
# Fetching page number: 92
# Fetching page number: 93
# Fetching page number: 94
# Fetching page number: 95
# Fetching page number: 96
# Fetching page number: 97
# Fetching page number: 98
# Fetching page number: 99
# Fetching page number: 100
# Fetching page number: 101
# Fetching page number: 102
# Fetching page number: 103
# Fetching page number: 104
# Fetching page number: 105
# Fetching page number: 106
# Fetching page number: 107
# Fetching page number: 108
# Fetching page number: 109
# Fetching page number: 110
# Fetching page number: 111
# Fetching page number: 112
# Fetching page number: 113
# Fetching page number: 114
# Fetching page number: 115
# Fetching page number: 116
# Fetching page number: 117
# Fetching page number: 118
# Fetching page number: 119
# Fetching page number: 120
# Fetching page number: 121
# Fetching page number: 122
# Fetching page number: 123
# Fetching page number: 124
# Fetching page number: 125
# Fetching page number: 126
# Fetching page number: 127
# Fetching page number: 128
# Fetching page number: 129
# Fetching page number: 130
# Fetching page number: 131
# Fetching page number: 132
# Fetching page number: 133
# Fetching page number: 134
# Fetching page number: 135
# Fetching page number: 136
# Fetching page number: 137
# Fetching page number: 138
# Fetching page number: 139
# Fetching page number: 140
# Fetching page number: 141
# Fetching page number: 142
# Fetching page number: 143
# Fetching page number: 144
# Fetching page number: 145
# Fetching page number: 146
# Fetching page number: 147
# Fetching page number: 148
# Fetching page number: 149
# Fetching page number: 150
# Fetching page number: 151
# Fetching page number: 152
# Fetching page number: 153
# Fetching page number: 154
# Fetching page number: 155
# Fetching page number: 156
# Fetching page number: 157
# Fetching page number: 158
# Fetching page number: 159
# Fetching page number: 160
# Fetching page number: 161
# Fetching page number: 162
# Fetching page number: 163
# Fetching page number: 164
# Fetching page number: 165
# Fetching page number: 166
# Fetching page number: 167
# Fetching page number: 168
# Fetching page number: 169
# Fetching page number: 170
# Fetching page number: 171
# Fetching page number: 172
# Fetching page number: 173
# Fetching page number: 174
# Fetching page number: 175
# Fetching page number: 176
# Fetching page number: 177
# Fetching page number: 178
# Fetching page number: 179
# Fetching page number: 180
# Fetching page number: 181
# Fetching page number: 182
# Fetching page number: 183
# Fetching page number: 184
# Fetching page number: 185
# Fetching page number: 186
# Fetching page number: 187
# Fetching page number: 188
# Fetching page number: 189
# Fetching page number: 190
# Fetching page number: 191
# Fetching page number: 192
# Fetching page number: 193
# Fetching page number: 194
# Fetching page number: 195
# Fetching page number: 196
# Fetching page number: 197
# Fetching page number: 198
# Fetching page number: 199
# Fetching page number: 200
# Fetching page number: 201
# Fetching page number: 202
# Fetching page number: 203
# Fetching page number: 204
# Fetching page number: 205
# Fetching page number: 206
# Fetching page number: 207
# Fetching page number: 208
# Fetching page number: 209
# Fetching page number: 210
# Fetching page number: 211
# Fetching page number: 212
# Fetching page number: 213
# Fetching page number: 214
# Fetching page number: 215
# Fetching page number: 216
# Fetching page number: 217
# Fetching page number: 218
# Fetching page number: 219
# Fetching page number: 220
# Fetching page number: 221
# Fetching page number: 222
# Fetching page number: 223
# Fetching page number: 224
# Fetching page number: 225
# Fetching page number: 226
# Fetching page number: 227
# Fetching page number: 228
# Fetching page number: 229
# Fetching page number: 230
# Fetching page number: 231
# Fetching page number: 232
# Fetching page number: 233
# Fetching page number: 234
# Fetching page number: 235
# Fetching page number: 236
# Fetching page number: 237
# Fetching page number: 238
# Fetching page number: 239
# Fetching page number: 240
# Fetching page number: 241
# Fetching page number: 242
# Fetching page number: 243
# Fetching page number: 244
# Fetching page number: 245
# Fetching page number: 246
# Fetching page number: 247
# Fetching page number: 248
# Fetching page number: 249
# Fetching page number: 250
# Fetching page number: 251
# Fetching page number: 252
# Fetching page number: 253
# Fetching page number: 254
# Fetching page number: 255
# Fetching page number: 256
# Fetching page number: 257
# Fetching page number: 258
# Fetching page number: 259
# Fetching page number: 260
# Fetching page number: 261
# Total issues fetched: 26022

# %%
import json
with open('issues.json', 'w') as f:
    json.dump(issues, f, indent=4)

# %%
issues[0]
# Out:
# {'title': '[DOM] Fix package.json files for #28784',
#  'body': 'Missed some files for the react-server disallow client change in #28784',
#  'created_at': '2024-04-08T22:41:51Z',
#  'closed_at': '2024-04-08T22:49:19Z',
#  'is_pull_request': True,
#  'author_association': 'COLLABORATOR'}
